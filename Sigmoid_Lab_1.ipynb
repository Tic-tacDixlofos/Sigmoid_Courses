# %% [markdown]
# Assumptions
# Steps
#
#
# - age: The person’s age in years
# - sex: The person’s sex (1 = male, 0 = female)
# - cp: chest pain type— Value 0: asymptomatic— Value 1: atypical angina— Value 2: non-anginal pain— Value 3: typical angina
# - trestbps: The person’s resting blood pressure (mm Hg on admission to the hospital)
# - chol: The person’s cholesterol measurement in mg/dl
# - fbs: The person’s fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
# - restecg: resting electrocardiographic results— Value 0: showing probable or definite left ventricular hypertrophy by Estes’ criteria— Value 1: normal— Value 2: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV)
# - thalach: The person’s maximum heart rate achieved
# - exang: Exercise induced angina (1 = yes; 0 = no)
# - oldpeak: ST depression induced by exercise relative to rest (‘ST’ relates to positions on the ECG plot. See more here)
# - slope: the slope of the peak exercise ST segment — 0: downsloping; 1: flat; 2: upsloping0: downsloping; 1: flat; 2: upsloping
# - ca: The number of major vessels (0–3)
# - thal: A blood disorder called thalassemia Value 0: NULL (dropped from the dataset previouslyValue 1: fixed defect (no blood flow in some part of the heart)Value 2: normal blood flowValue 3: reversible defect (a blood flow is observed but it is not normal)
# - target: Heart disease (1 = no, 0= yes)

# %% [markdown]
# - Study each column together and separate it from others in relation with the ***target*** column. I highly recommend you to explore the following statistical parameters:
#     - Create a jupyter notebook with a clean code.
#     - Mean.
#     - Median.
#     - Mode.
#     - Standard Deviation.
#     - Variation.
#     - Range of values.
#
# - Find what columns have the highest absolute correlation with the ***target*** column (target column is specified in the data set page), and try to explain why do you think so happens. (here you can explore literature on topic.)

# %%
import pandas as pd #I immported the libraries i need to use for my task pandas for manipulating tables and some datat visualisation

# %%
#I want to use data and visualise the fiarst dates

dt=pd.read_csv("heart.csv")

dt.head() # I used propoed graphs for data analysi and better unerdtanding
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
dt.info # its an additional step which can show some informatyin before using th library
# Out:
# <bound method DataFrame.info of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
dt.describe() #we may see here the exact dates ill present lower like: mean, median etc...
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# I will follow the task so im starting with "Mean"
#Mean is the sum of all values in a numerical series divided by the number of values in the series

mean=dt.mean()


# Then ill continue with a "Median" a value in the middle of two odd parts if in the middle there are two even parts then  the median will be in two values

madian = dt.median()


#    "Mode"  the most frequent value "In my assumption it will be good used for better statistical values"

mode=dt.mode()

# Standart deviation
#and the standard deviation of a feature x are the same thing
#Measures: How spread out the values in a single column are
#Type: Univariate (looks at one column)
devitation=dt.std()


#Measures: How two columns vary together (relationship between columns)
#looks at pairs of columns

correlation = dt.corr()
# correlation between the columns


#Variation. The variance is a measure of how much the values of each attribute deviate from its mean value.

variation = dt.var()
#Range of values. We can batter analyse the mistakes or te data range for better understandung for trainging model

rofval = dt.max() - dt.min()

# %%
print(mean)
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %%
print(madian)
# Out:
# age          55.0
# sex           1.0
# cp            1.0
# trestbps    130.0
# chol        240.0
# fbs           0.0
# restecg       1.0
# thalach     153.0
# exang         0.0
# oldpeak       0.8
# slope         1.0
# ca            0.0
# thal          2.0
# target        1.0
# dtype: float64

# %%
# Mode
mode = dt.mode().iloc[0]  # .helps with replacing missng alues bacuse i had a lot of nan values

#Replace missng values
dt_filled = dt.fillna(mode)

print(mode)

print("\nDataFrame после замены пропусков")
print(dt_filled)
print(mode)
# Out:
# age          58.0
# sex           1.0
# cp            0.0
# trestbps    120.0
# chol        197.0
# fbs           0.0
# restecg       1.0
# thalach     162.0
# exang         0.0
# oldpeak       0.0
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 0, dtype: float64
#
# DataFrame после замены пропусков
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# ...

# %%
print(devitation)
# Out:
# age          9.082101
# sex          0.466011
# cp           1.032052
# trestbps    17.538143
# chol        51.830751
# fbs          0.356198
# restecg      0.525860
# thalach     22.905161
# exang        0.469794
# oldpeak      1.161075
# slope        0.616226
# ca           1.022606
# thal         0.612277
# target       0.498835
# dtype: float64

# %%
print(correlation)
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
print(variation)
# Out:
# age           82.484558
# sex            0.217166
# cp             1.065132
# trestbps     307.586453
# chol        2686.426748
# fbs            0.126877
# restecg        0.276528
# thalach      524.646406
# exang          0.220707
# oldpeak        1.348095
# slope          0.379735
# ca             1.045724
# thal           0.374883
# target         0.248836
# dtype: float64

# %%
print(rofval)
# Out:
# age          48.0
# sex           1.0
# cp            3.0
# trestbps    106.0
# chol        438.0
# fbs           1.0
# restecg       2.0
# thalach     131.0
# exang         1.0
# oldpeak       6.2
# slope         2.0
# ca            4.0
# thal          3.0
# target        1.0
# dtype: float64

# %%
correlation_with_target = dt.corr()['target'].abs().sort_values(ascending=False)

# Display correlation
print(correlation_with_target)
# Out:
# target      1.000000
# exang       0.436757
# cp          0.433798
# oldpeak     0.430696
# thalach     0.421741
# ca          0.391724
# slope       0.345877
# thal        0.344029
# sex         0.280937
# age         0.225439
# trestbps    0.144931
# restecg     0.137230
# chol        0.085239
# fbs         0.028046
# Name: target, dtype: float64

# %% [markdown]
# We see the maximum positive correlation between target and : exang, cp,     oldpeak, thalach the most lower correlation we see netweeen fbs and chol
